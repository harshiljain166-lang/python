# %%
import pandas as pd

# %%
a={
    'Name':['jatin','abahy','vishal','tanmay','rohit','romit','rahul'],
    'age':[25,36,21,36,24,41,56],
    'score':[96,25,45,78,40,56,23]

}
data=pd.DataFrame(a)
data
# Out:
#      Name  age  score
# 0   jatin   25     96
# 1   abahy   36     25
# 2  vishal   21     45
# 3  tanmay   36     78
# 4   rohit   24     40
# 5   romit   41     56
# 6   rahul   56     23

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    7 non-null      object
#  1   age     7 non-null      int64
#  2   score   7 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 300.0+ bytes

# %%
data.head()#top 5 rows
# Out:
#      Name  age  score
# 0   jatin   25     96
# 1   abahy   36     25
# 2  vishal   21     45
# 3  tanmay   36     78
# 4   rohit   24     40

# %%
data.shape
# Out:
# (7, 3)

# %%
data.tail()
# Out:
#      Name  age  score
# 2  vishal   21     45
# 3  tanmay   36     78
# 4   rohit   24     40
# 5   romit   41     56
# 6   rahul   56     23

# %%
data.dtypes
# Out:
# Name     object
# age       int64
# score     int64
# dtype: object

# %% [markdown]
# **selecting rows and columns**

# %%
data[['Name','age']]
# Out:
#      Name  age
# 0   jatin   25
# 1   abahy   36
# 2  vishal   21
# 3  tanmay   36
# 4   rohit   24
# 5   romit   41
# 6   rahul   56

# %%
data.loc[4,'Name']
#.loc(df.loc[row_label,col_label])
# Out:
# 'rohit'

# %%
data.loc[1:4,['Name','age']]
# Out:
#      Name  age
# 1   abahy   36
# 2  vishal   21
# 3  tanmay   36
# 4   rohit   24

# %%
#.iloc(row_index,col_index)
data.iloc[3]
# Out:
# Name     tanmay
# age          36
# score        78
# Name: 3, dtype: object

# %%
data.iloc[0:3,0:2]
# Out:
#      Name  age
# 0   jatin   25
# 1   abahy   36
# 2  vishal   21

# %%
data.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
data.values
# Out:
# array([['jatin', 25, 96],
#        ['abahy', 36, 25],
#        ['vishal', 21, 45],
#        ['tanmay', 36, 78],
#        ['rohit', 24, 40],
#        ['romit', 41, 56],
#        ['rahul', 56, 23]], dtype=object)

# %%
data.columns
# Out:
# Index(['Name', 'age', 'score'], dtype='object')

# %%
data.values.shape
# Out:
# (7, 3)
